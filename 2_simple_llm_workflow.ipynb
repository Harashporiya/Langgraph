# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=os.getenv("GOOGLE_API_KEY"),
    temperature=0,
)

# %%
# create a state

class LLMState(TypedDict):

    question:str
    answer:str

# %%
def llm_qa(state: LLMState) -> LLMState:
    # Extract the question from state
    question = state["question"]

    # Create a prompt
    prompt = f"Answer the following question: {question}"

    # Ask the question to the LLM
    answer = model.invoke(prompt).content

    # Update the answer in the state
    state["answer"] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add node

graph.add_node('llm_qa',llm_qa)

# add edges
graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)

# complie
workflow = graph.compile()

# %%
#execute
inital_state ={'question': "How far is moon from the earth?"}

final_state = workflow.invoke(inital_state)

print(final_state['answer'])
# Out:
# The distance between the Earth and the Moon is not constant due to the Moon's elliptical orbit, but here are the key figures:
#
# *   **Average Distance:** Approximately **384,400 kilometers** (238,900 miles)
# *   **Closest Point (Perigee):** Around **363,104 kilometers** (225,623 miles)
# *   **Farthest Point (Apogee):** Around **405,696 kilometers** (252,088 miles)
#
# So, on average, you can say the Moon is about **384,400 km** or **238,900 miles** away.
